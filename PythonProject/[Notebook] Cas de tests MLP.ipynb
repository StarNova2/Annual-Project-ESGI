# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import ctypes

from numpy import dtype
from pandas.core.dtypes.cast import maybe_downcast_to_dtype

from rust_bridge import MLPRust,TaskMode

lib = ctypes.cdll.LoadLibrary('../lib_classification/target/release/lib_classification.dll')

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Linear Simple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
], dtype=np.float32)
Y = np.array([
      1,
      -1,
      -1
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
mlp = MLPRust(
        layer_sizes=[2,1],
        learning_rate=0.001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=1000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

for i in range(-10,41):
    for j in range(-10,41):
        points_to_predict.append((i/10,j/10))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

for p in points_to_predict:
    if mlp.predict_labels(p) == -1:
        labels.append(1.0)
        colors.append('lightblue')
    else:
        labels.append(-1.0)
        colors.append('pink')

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(X[0, 0], X[0, 1], color='red')
plt.scatter(X[1:3,0], X[1:3,1], color='blue')

plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.show()
plt.clf()

for i in range(len(X)):
    pred = lib.linear_classification_prediction(w.a, w.b, w.c,1.0, X[i][0], X[i][1])
    print(i, pred, Y[i])
# Out:
# 0 1.0 1.0
# 1 -1.0 -1.0
# 2 -1.0 -1.0

# %% [markdown]
# ### Linear Multiple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.concatenate(
    [
        np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])
    ], dtype=np.float32
    )
Y = np.concatenate(
    [
        np.ones((50,1), dtype=np.float32), np.ones((50,1),dtype=np.float32) * -1.0
    ]
    )

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
try :
    mlp.close()
except:
    pass

mlp = MLPRust(
        layer_sizes=[2,1],
        learning_rate=0.001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=10000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

points_to_predict = []

for i in range(100):
    for j in range(100):
        points_to_predict.append((i/10,j/10))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

for p in points_to_predict:
    if mlp.predict_labels(p) == -1:
        labels.append(1.0)
        colors.append('pink')
    else:
        labels.append(-1.0)
        colors.append('lightblue')

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.show()
plt.clf()

# %% [markdown]
# ### XOR :
#         Linear Model    : KO
#         MLP (2, 2, 1)   : OK

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
try :
    mlp.close()
except:
    pass

mlp = MLPRust(
        layer_sizes=[2,2,1],
        learning_rate=0.001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=10000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

for i in range(101):
    for j in range(101):
        points_to_predict.append((i/100,j/100))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

for p in points_to_predict:
    if mlp.predict_labels(p) == -1:
        labels.append(1.0)
        colors.append('pink')
    else:
        labels.append(-1.0)
        colors.append('lightblue')

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Cross :
#         Linear Model    : KO
#         MLP (2, 4, 1)   : OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
try :
    mlp.close()
except:
    pass

mlp = MLPRust(
        layer_sizes=[2,4,1],
        learning_rate=0.0001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=100000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

for i in range(-100,100):
    for j in range(-100,100):
        points_to_predict.append((i/100,j/100))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

for p in points_to_predict:
    if mlp.predict_labels(p) == -1:
        labels.append(1.0)
        colors.append('pink')
    else:
        labels.append(-1.0)
        colors.append('lightblue')

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # ----- MLP MODEL PREDICTED POINTS -----
# ----> 2 plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)
#       3
#       4 plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
#       5 plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
#
# NameError: name 'points_to_predict' is not defined

# %% [markdown]
# ### Multi Linear 3 classes :
#         Linear Model x3 : OK
#         MLP (2, 3)      : OK

# %%
X = (np.random.random((500, 2)) * 2.0 - 1.0).astype(np.float32)
Y = np.array([[1, -1, -1] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, 1, -1] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, -1, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else
              [-1, -1, -1]for p in X]).astype(np.float32)

X = X[[not np.all(arr == [-1, -1, -1]) for arr in Y]]
Y = Y[[not np.all(arr == [-1, -1, -1]) for arr in Y]]

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
try :
    mlp.close()
except:
    pass

mlp = MLPRust(
        layer_sizes=[2,3],
        learning_rate=0.001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=10000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

for i in range(-100,100):
    for j in range(-100,100):
        points_to_predict.append((i/100,j/100))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

test = set()

for p in points_to_predict:
    if (mlp.predict_labels(p)[0] == [1,-1,-1]).all():
        labels.append(1.0)
        colors.append('lightblue')
    elif (mlp.predict_labels(p)[0] == [-1,1,-1]).all():
        labels.append(0.0)
        colors.append('pink')
    else:
        labels.append(-1.0)
        colors.append('lightgreen')

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Cross :
#         Linear Model x3 : KO
#         MLP (2, ?, ?, 3): OK

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, -1, -1] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [-1, 1, -1] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [-1, -1, 1] for p in X])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
try :
    mlp.close()
except:
    pass

mlp = MLPRust(
        layer_sizes=[2,3,3,3],
        learning_rate=0.00001,
        task_mode=TaskMode.CLASSIFICATION,
    )

# %% [markdown]
# ##### MODEL TRAINING

# %%
mlp.fit(X, Y, steps=10000000)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []

for i in range(-100,100):
    for j in range(-100,100):
        points_to_predict.append((i/100,j/100))
points_to_predict = np.array(points_to_predict)

labels = []
colors = []

# for p in points_to_predict:
#     if (mlp.predict_labels(p)[0] == [-1,-1,1]).all():
#         labels.append(1.0)
#         colors.append('lightblue')
#     elif (mlp.predict_labels(p)[0] == [-1,1,-1]).all():
#         labels.append(0.0)
#         colors.append('pink')
#     else:
#         labels.append(-1.0)
#         colors.append('lightgreen')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 16
#      12 points_list = []
#      13 for p in points_to_predict:
#      14     points_list.append(mlp.predict_labels(p))
#      15
# ---> 16 points_list = set(points_list)
#      17
#      18 # for p in points_to_predict:
#      19 #     if (mlp.predict_labels(p)[0] == [-1,-1,1]).all():
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :
#         Linear Model : OK
#         MLP (1, 1)   : OK

# %%
X = np.array([
      [1],
      [2]
], dtype=np.float32)
Y = np.array([
      2,
      3
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict[:, 0], points_to_predict[:, 1], c=colors)

plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 2D :
#         Linear Model    : OK
#         MLP (1, ?, 1)   : OK

# %%
X = np.array([
      [1],
      [2],
      [3]
], dtype=np.float32)
Y = np.array([
      2,
      3,
      2.5
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Simple 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
], dtype=np.float32)
Y = np.array([
      2,
      3,
      2.5
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Tricky 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
], dtype=np.float32)
Y = np.array([
      1,
      2,
      3
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 3D :
#         Linear Model       : KO
#         MLP (2, 2, 1)      : OK

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
], dtype=np.float32)
Y = np.array([
      2,
      1,
      -2,
      -1
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()
