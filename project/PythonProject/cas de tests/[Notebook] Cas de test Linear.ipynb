# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import ctypes

from numpy import dtype
from pandas.core.dtypes.cast import maybe_downcast_to_dtype

from rust_bridge import MLPRust,TaskMode

lib = ctypes.cdll.LoadLibrary('../lib_classification/target/release/lib_classification.dll')

class MyDroite(ctypes.Structure):_fields_ = [
    ("a", ctypes.c_float),
    ("b", ctypes.c_float),
    ("c", ctypes.c_float),
]

lib.initialisation_droite.restype = ctypes.POINTER(MyDroite)
lib.training.argtypes = [ctypes.c_float, ctypes.c_int32, ctypes.c_int32, MyDroite, ctypes.POINTER(ctypes.c_float), ctypes.POINTER(ctypes.c_float)]
lib.training.restype = ctypes.POINTER(MyDroite)
lib.linear_classification_prediction.restype = ctypes.c_float
lib.linear_classification_prediction.argtypes = [
        ctypes.c_float,
        ctypes.c_float,
        ctypes.c_float,
        ctypes.c_float,
        ctypes.c_float,
        ctypes.c_float
    ]

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Linear Simple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
], dtype=np.float32)
Y = np.array([
      1,
      -1,
      -1
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
ma_droite = lib.initialisation_droite()
a = ma_droite.contents.a
b = ma_droite.contents.b
c = ma_droite.contents.c
w = MyDroite(a, b, c)

data_ptr = X.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

labels_ptr = Y.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

# %% [markdown]
# ##### MODEL TRAINING

# %%
w = lib.training(ctypes.c_float(0.01), 10000000, len(X), w, data_ptr, labels_ptr)
w = w.contents

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict_ = []
predicted_colors = []
for row in range(100):
  for col in range(100):
    point_to_predict_ = [1.0, row/10.0, col/10.0]
    points_to_predict_.append(point_to_predict_)
    predicted_colors.append(
        'lightblue' if lib.linear_classification_prediction(w.a,w.b, w.c, point_to_predict_[0] ,point_to_predict_[1],point_to_predict_[2] ) >= 0 else 'pink')
points_to_predict_ = np.array(points_to_predict_)

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict_[:, 1], points_to_predict_[:, 2], c=predicted_colors)

plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.show()
plt.clf()

for i in range(len(X)):
    pred = lib.linear_classification_prediction(w.a, w.b, w.c,1.0, X[i][0], X[i][1])
    print(i, pred, Y[i])

# %% [markdown]
# ### Linear Multiple :
#         Linear Model : OK
#         MLP (2, 1)   : OK

# %%
X = np.concatenate(
    [
        np.random.random((50,2)) * 0.9 + np.array([1, 1]), np.random.random((50,2)) * 0.9 + np.array([2, 2])
    ], dtype=np.float32
    )
Y = np.concatenate(
    [
        np.ones((50,1), dtype=np.float32), np.ones((50,1),dtype=np.float32) * -1.0
    ]
    )

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
ma_droite1 = lib.initialisation_droite()
a = ma_droite1.contents.a
b = ma_droite1.contents.b
c = ma_droite1.contents.c
w = MyDroite(a, b, c)

data_ptr = X.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

labels_ptr = Y.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

# %% [markdown]
# ##### MODEL TRAINING

# %%
w = lib.training(ctypes.c_float(0.01), 10000000, len(X), w, data_ptr, labels_ptr)
w = w.contents

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict_ = []
predicted_colors = []
for row in range(100):
  for col in range(100):
    point_to_predict = [1.0, row/10.0, col/10.0]
    points_to_predict_.append(point_to_predict)
    predicted_colors.append(
        'lightblue' if lib.linear_classification_prediction(w.a,w.b, w.c, point_to_predict[0] ,point_to_predict[1],point_to_predict[2] ) >= 0 else 'pink')
points_to_predict_ = np.array(points_to_predict_)

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict_[:, 1], points_to_predict_[:, 2], c=predicted_colors)

plt.scatter(X[0:50, 0], X[0:50, 1], color='blue')
plt.scatter(X[50:100,0], X[50:100,1], color='red')
plt.xlim(-1, 4)
plt.ylim(-1, 4)
plt.show()
plt.clf()

# %% [markdown]
# ### XOR :
#         Linear Model    : KO
#         MLP (2, 2, 1)   : OK

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# ##### MODEL TRAINING

# %% [markdown]
# ##### MODEL PREDICTION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(X[0:2, 0], X[0:2, 1], color='blue')
plt.scatter(X[2:4,0], X[2:4,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Cross :
#         Linear Model    : KO
#         MLP (2, 4, 1)   : OK

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# ##### MODEL TRAINING

# %% [markdown]
# ##### MODEL PREDICTION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]] == -1, enumerate(X)))))[:,1], color='red')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Linear 3 classes :
#         Linear Model x3 : OK
#         MLP (2, 3)      : OK

# %%
X = (np.random.random((500, 2)) * 2.0 - 1.0).astype(np.float32)
Y = np.array([[1, -1, -1] if -p[0] - p[1] - 0.5 > 0 and p[1] < 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, 1, -1] if -p[0] - p[1] - 0.5 < 0 and p[1] > 0 and p[0] - p[1] - 0.5 < 0 else
              [-1, -1, 1] if -p[0] - p[1] - 0.5 < 0 and p[1] < 0 and p[0] - p[1] - 0.5 > 0 else
              [-1, -1, -1]for p in X]).astype(np.float32)

X = X[[not np.all(arr == [-1, -1, -1]) for arr in Y]]
Y = Y[[not np.all(arr == [-1, -1, -1]) for arr in Y]]

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %%
ma_droite = lib.initialisation_droite()
a = ma_droite.contents.a
b = ma_droite.contents.b
c = ma_droite.contents.c
w1 = MyDroite(a, b, c)

ma_droite = lib.initialisation_droite()
a = ma_droite.contents.a
b = ma_droite.contents.b
c = ma_droite.contents.c
w2 = MyDroite(a, b, c)

ma_droite = lib.initialisation_droite()
a = ma_droite.contents.a
b = ma_droite.contents.b
c = ma_droite.contents.c
w3 = MyDroite(a, b, c)

data_ptr = X.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

Y1 = Y[:, 0].astype(np.float32)
Y2 = Y[:, 1].astype(np.float32)
Y3 = Y[:, 2].astype(np.float32)


labels_ptr1 = Y1.ctypes.data_as(ctypes.POINTER(ctypes.c_float))
labels_ptr2 = Y2.ctypes.data_as(ctypes.POINTER(ctypes.c_float))
labels_ptr3 = Y3.ctypes.data_as(ctypes.POINTER(ctypes.c_float))

# %% [markdown]
# ##### MODEL TRAINING

# %%
w1 = lib.training(ctypes.c_float(0.001), 10000, len(X), w1, data_ptr, labels_ptr1)
w1 = w1.contents

w2 = lib.training(ctypes.c_float(0.001), 100000, len(X), w2, data_ptr, labels_ptr2)
w2 = w2.contents

w3 = lib.training(ctypes.c_float(0.0001), 100000, len(X), w3, data_ptr, labels_ptr3)
w3 = w3.contents

#print(w1.a, w1.b, w1.c)
#print(w2.a, w2.b, w2.c)
#print(w3.a, w3.b, w3.c)

# %% [markdown]
# ##### MODEL PREDICTION

# %%
points_to_predict = []
predicted_colors = []
for row, col in points_to_predict:
    point_to_predict = [1.0, row, col]
    points_to_predict_.append(point_to_predict)
    predicted_colors.append('lightblue' if lib.linear_classification_prediction(w1.a,w1.b, w1.c, point_to_predict[0] ,point_to_predict[1],point_to_predict[2] ) >= 0 else
                            'lightgreen' if lib.linear_classification_prediction(w3.a,w3.b, w3.c, point_to_predict[0] ,point_to_predict[1],point_to_predict[2] ) >= 0 else
                            'pink' if lib.linear_classification_prediction(w2.a,w2.b, w2.c, point_to_predict[0] ,point_to_predict[1],point_to_predict[2] ) >= 0 else 'white')
points_to_predict_ = np.array(points_to_predict_)

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(points_to_predict_[:, 1], points_to_predict_[:, 2], c=predicted_colors)

plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ### Multi Cross :
#         Linear Model x3 : KO
#         MLP (2, ?, ?, 3): OK

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, -1, -1] if abs(p[0] % 0.5) <= 0.25 and abs(p[1] % 0.5) > 0.25 else [-1, 1, -1] if abs(p[0] % 0.5) > 0.25 and abs(p[1] % 0.5) <= 0.25 else [-1, -1, 1] for p in X])

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# ##### MODEL TRAINING

# %% [markdown]
# ##### MODEL PREDICTION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][0] == 1, enumerate(X)))))[:,1], color='blue')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][1] == 1, enumerate(X)))))[:,1], color='red')
plt.scatter(np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,0], np.array(list(map(lambda elt : elt[1], filter(lambda c: Y[c[0]][2] == 1, enumerate(X)))))[:,1], color='green')
plt.show()
plt.clf()

# %% [markdown]
# ## Régression

# %% [markdown]
# ### Linear Simple 2D :
#         Linear Model : OK
#         MLP (1, 1)   : OK

# %%
X = np.array([
      [1],
      [2]
], dtype=np.float32)
Y = np.array([
      2,
      3
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 2D :
#         Linear Model    : OK
#         MLP (1, ?, 1)   : OK

# %%
X = np.array([
      [1],
      [2],
      [3]
], dtype=np.float32)
Y = np.array([
      2,
      3,
      2.5
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
plt.scatter(X,Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Simple 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
], dtype=np.float32)
Y = np.array([
      2,
      3,
      2.5
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Linear Tricky 3D :
#         Linear Model    : OK
#         MLP (2, 1)      : OK

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
], dtype=np.float32)
Y = np.array([
      1,
      2,
      3
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()

# %% [markdown]
# ### Non Linear Simple 3D :
#         Linear Model       : KO
#         MLP (2, 2, 1)      : OK

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
], dtype=np.float32)
Y = np.array([
      2,
      1,
      -2,
      -1
], dtype=np.float32)

# %% [markdown]
# #### CODE ADDED :

# %% [markdown]
# ##### MODEL INITIALIZATION

# %% [markdown]
# #### PLOT CREATION

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],Y)
plt.show()
plt.clf()
